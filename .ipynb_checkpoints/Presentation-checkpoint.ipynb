# %% [markdown]
# # Analysis on NBA Players from 2012-2017:

# %% [markdown]
# ### Lucas Han and Alick Zhang

# %%
from IPython.display import Image
import pandas as pd

# %%
Image("nba-players.jpg")

# %% [markdown]
# ## Research Question:

# %% [markdown]
# - What factors affect a player's average points per game?
# - Who were the top 5 shooters (highest average points per game) in the 2017-18 season?

# %% [markdown]
# ## Data Collection and Cleaning:

# %% [markdown]
# We decided to scrape the statistics of every player and team from basketball-reference.com. We focused on years 2012 to 2017 to make predictions on the average points per game in 2017-18 season.

# %% [markdown]
# First, we scraped information on players. We combined two dataframes to get both performance statistics, height, and weight.

# %%
Image("player-info.png")

# %%
Image("player-stats.png")

# %% [markdown]
# Then, we gathered information on the teams. We were able to scrape information to determine the team's division, conference, and finish.

# %%
Image("conference.png")

# %%
Image("finish.png")

# %% [markdown]
# After combining all of the dataframes, we created our final dataframe with the following columns:

# %%
final_df = pd.read_csv("/Users/lhan/Desktop/Senior/DATA301/final_project/player.csv")
final_df.head()
# Out:
#              name  season   age team_id pos     g    gs  mp_per_g  fg_pct  \
# 0    Alex Abrines  2016.0  23.0     OKC  SG  68.0   6.0      15.5   0.393
# 1    Steven Adams  2016.0  23.0     OKC   C  80.0  80.0      29.9   0.571
# 2  Semaj Christon  2016.0  24.0     OKC  PG  64.0   1.0      15.2   0.345
# 3     Norris Cole  2016.0  28.0     OKC  PG  13.0   0.0       9.6   0.308
# 4   Nick Collison  2016.0  36.0     OKC  PF  20.0   0.0       6.4   0.609
#
#    fg3_per_g   ...    pf_per_g  pts_per_g  height  weight  wins  losses  \
# 0        1.4   ...         1.7        6.0      78     200  47.0    35.0
# 1        0.0   ...         2.4       11.3      84     265  47.0    35.0
# 2        0.2   ...         1.2        2.9      75     190  47.0    35.0
# 3        0.2   ...         1.4        3.3      74     175  47.0    35.0
# 4        0.0   ...         0.9        1.7      82     255  47.0    35.0
#
#    rank_team   division  conference  finish
# ...

# %% [markdown]
# ## Data Exploration:

# %% [markdown]
# ## What are the general trends in terms of offense within the NBA?

# %% [markdown]
# - Average Field Goal Attempted Per Game

# %%
Image("image4.png")

# %% [markdown]
# - Average Points Per Game

# %%
Image("image6.png")

# %% [markdown]
# - 3 Point Shots Attempted Per Game by Division

# %%
Image("image7.png")

# %% [markdown]
# - 3 Pointers Attempted by Team

# %%
Image("image11.png")

# %% [markdown]
# - 3 Point Made Per Game by Team

# %%
Image("image9.png")

# %%
Image("image10.png")

# %% [markdown]
# Here are some of the visualizations we created to answer the following questions:

# %% [markdown]
# **How are position split by team?**

# %%
Image("image1.png")

# %% [markdown]
# **What are the positions that have the highest average points per game?**

# %%
Image("image2.png")

# %% [markdown]
# ## Machine Learning:

# %% [markdown]
# **Predicting each player's average points per game for 2017-18 season:**

# %% [markdown]
# Features set:
# - name, height, weight, position, games played, minutes per game, effective field goal percentage, free throw percentage

# %% [markdown]
# ML models:
#
# - K Nearest Neighbors Regressor
# - Random Forest Regressor
# - Ensembler Method with KNN and RandomForest

# %% [markdown]
# Scaler methods:
#
# - StandardScaler
# - Normalizer
# - MinMaxScaler
# - RobustScaler

# %% [markdown]
# **Model and feature selection, hyperparameter tuning, and best value for K:**

# %% [markdown]
# Model - `RegressionEnsembler (KNN and RandomForest)`
#
# Features - `['name', 'height', 'weight', 'pos', 'mp_per_g', 'efg_pct', 'ft_pct']`
#
# Scaler method - `StandardScaler`
#
# Value for K - `42`

# %%
Image("predictions.png")

# %%
Image("actual.png")
