# %% [markdown]
# # Data Exploration

# %%
# Import statements
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# First, we read in the csv file that we created from the data collection and cleaning notebook.

# %%
final_df = pd.read_csv("/Users/alickzhang/desktop/dataproject/nba_player_ml/player.csv")
final_df.head()
# Out:
#              name  season   age team_id pos     g    gs  mp_per_g  fg_pct  \
# 0    Alex Abrines  2016.0  23.0     OKC  SG  68.0   6.0      15.5   0.393
# 1    Steven Adams  2016.0  23.0     OKC   C  80.0  80.0      29.9   0.571
# 2  Semaj Christon  2016.0  24.0     OKC  PG  64.0   1.0      15.2   0.345
# 3     Norris Cole  2016.0  28.0     OKC  PG  13.0   0.0       9.6   0.308
# 4   Nick Collison  2016.0  36.0     OKC  PF  20.0   0.0       6.4   0.609
#
#    fg3_per_g   ...    pf_per_g  pts_per_g  height  weight  wins  losses  \
# 0        1.4   ...         1.7        6.0      78     200  47.0    35.0
# 1        0.0   ...         2.4       11.3      84     265  47.0    35.0
# 2        0.2   ...         1.2        2.9      75     190  47.0    35.0
# 3        0.2   ...         1.4        3.3      74     175  47.0    35.0
# 4        0.0   ...         0.9        1.7      82     255  47.0    35.0
#
#    rank_team   division  conference  finish
# ...

# %% [markdown]
# ### How are position split by team?

# %%
pos_counts = final_df["pos"].value_counts()
pos_counts.plot.pie()

# %% [markdown]
# **Conclusion:**
#
# The positions are divided evenly for all the players in the NBA.

# %% [markdown]
# ### What are the positions that have the highest average points per game?

# %%
pos_pts_cube = final_df.pivot_table(
    index="pos",
    values="pts_per_g", aggfunc=np.mean)
pos_pts_cube.sort_values("pts_per_g").plot.bar(figsize=(20,8))

# %% [markdown]
# **Conclusion:**
#
# The shooting guard and point guard tend to have the highest average points per game.

# %% [markdown]
# ### What is the relationship between season, positions, and points per game?

# %%
season_pts_cube = final_df.pivot_table(
    index="season", columns="pos",
    values="pts_per_g", aggfunc=np.mean)
season_pts_cube.plot.bar(figsize=(20,8))

# %%
team_div_df.columns
# Out:
# Index(['season', 'lg_id', 'team_id', 'wins', 'losses', 'rank_team', 'avg_age',
#        'avg_ht', 'avg_wt', 'g', 'mp_per_g', 'fg_per_g', 'fga_per_g', 'fg_pct',
#        'fg3_per_g', 'fg3a_per_g', 'fg3_pct', 'fg2_per_g', 'fg2a_per_g',
#        'fg2_pct', 'ft_per_g', 'fta_per_g', 'ft_pct', 'orb_per_g', 'drb_per_g',
#        'trb_per_g', 'ast_per_g', 'stl_per_g', 'blk_per_g', 'tov_per_g',
#        'pf_per_g', 'pts_per_g', 'division', 'conference', 'finish'],
#       dtype='object')

# %% [markdown]
# ### Explore the trend of data for variables related to points
# - FGA Per Game by Season

# %%
team_div_df = pd.read_csv("team_div.csv")

team_div_df.groupby("season")["fga_per_g"].mean().plot.line()
fig = plt.gcf()
fig.set_size_inches(16,6)
ax = plt.gca()
ax.set_xlabel("Season")
ax.set_ylabel("Average FGA Per Game")
# Out:
# Text(0, 0.5, 'Average FGA Per Game')

# %% [markdown]
# - Points per Game by Season

# %%
team_div_df.groupby("season")["pts_per_g"].mean().plot.line()
fig = plt.gcf()
fig.set_size_inches(16,6)
ax = plt.gca()
ax.set_xlabel("Season")
ax.set_ylabel("Average FGA Per Game")
# Out:
# Text(0, 0.5, 'Average FGA Per Game')

# %% [markdown]
# ### What caused this increase in points/pace?

# %% [markdown]
# - 3 Point Attemped by Conference and Season
#     - We see a positive increase in 3 point field goals attemped across all divisions over the seasons

# %%
team_div_df.groupby(["season", "division"])["fg3a_per_g"].mean().unstack().plot.bar()
fig = plt.gcf()
fig.set_size_inches(16,6)
plt.xlabel("")
plt.ylabel("3 Points Attempted")
# Out:
# Text(0, 0.5, '3 Points Attempted')

# %% [markdown]
# ### What teams are utilizing this new style of basketball?
# - HOU seems to make the most 3 point shots per game compared to all other teams

# %%
team_div_df.boxplot("fg3_per_g", by = "team_id")
fig = plt.gcf()
fig.set_size_inches(16,6)
ax = plt.gca()
plt.title("")
ax.set_ylabel("3 Pointers Made")
ax.set_xlabel("")
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# ### Which team is most efficient at shooting 3's?
# - Warriors seem to have the highest 3 point shooting percentage. Surprising to see Houston not be in the top 10.

# %%
team_div_df.boxplot("fg3_pct", by = "team_id")
fig = plt.gcf()
fig.set_size_inches(16,6)
ax = plt.gca()
plt.titlae("")
ax.set_ylabel("3 Point %")
ax.set_xlabel("")
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# ### Other factors that affect the score?
# - 2 Point FG
# - FT

# %%
team_div_df.boxplot("fg2_per_g", by = "team_id")
fig = plt.gcf()
fig.set_size_inches(16,6)

# %% [markdown]
# We see that HOU seems to make the lowest amount of 2 point shots

# %%
team_div_df.boxplot("fg2_pct", by = "team_id")
fig = plt.gcf()
fig.set_size_inches(16,6)

# %% [markdown]
# We see that in terms of efficiency in the mid-range shots, HOU seems to be teh best. We may want to suggest to the HOU to shoot more 2 point shots

# %% [markdown]
# - Freethrow Per Game

# %%
team_div_df.boxplot("ft_per_g", by = "team_id")
fig = plt.gcf()
fig.set_size_inches(16,6)

# %% [markdown]
# - FT Attemps Per Game

# %%
team_div_df.boxplot("fta_per_g", by = "team_id")
fig = plt.gcf()
fig.set_size_inches(16,6)
